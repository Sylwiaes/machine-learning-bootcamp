# %% [markdown]
# <a href="https://colab.research.google.com/github/Sylwiaes/machine-learning-bootcamp/blob/main/03_wizualizacje_danych/01_matplotlib_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * @author: krakowiakpawel9@gmail.com
# * @site: e-smartdata.org

# %% [markdown]
# ### Matplotlib
# >Strona biblioteki: [https://matplotlib.org/](https://matplotlib.org/)
# >Dokumentacja: [https://matplotlib.org/contents.html](https://matplotlib.org/contents.html)
# >
# >Matplotlib jest podstawową biblioteką do wizualizacji danych w języku Python.
# >Aby zainstalować bibliotekę matplotlib, użyj polecenia poniżej:
# ```
# pip install matplotlib
# ```
#
# ### Spis treści:
# 1. [Wykres liniowy](#1)
# 2. [Tworzenie wielu wykresów](#2)
# 3. [Wykresy słupkowe](#3)
# 4. [Wykresy punktowe](#4)

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.2.2'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
fig = plt.figure()
fig.show()

# %% [markdown]
# ### <a name='1'></a> Wykres liniowy

# %%
_ = plt.plot([0, 1], [0, 3])

# %%
plt.plot([0, 1], [0, 3], label='line', color='green')
plt.xlabel('oś x')
plt.ylabel('oś y')
plt.title('Wykres')
_ = plt.legend() #legenda

# %%
plt.plot([0, 1, 2], [0, 3, 2], label='line', color='green')
plt.xlabel('oś x')
plt.ylabel('oś y')
plt.title('Wykres')
_ = plt.legend()

# %%
x = np.arange(-3, 3, 0.1)
x_sin = np.sin(x)
x_cos = np.cos(x)

plt.plot(x, x_sin)
_ = plt.plot(x, x_cos)

# %%
x = np.arange(-3, 3, 0.1)
x_tan = np.tan(x)
x_ctan = np.arctan(x)

plt.plot(x, x_tan)
_ = plt.plot(x, x_ctan)

# %% [markdown]
# ### <a name='2'> </a> Tworzenie wielu wykresów

# %%
plt.subplot(121) #subplot - tworzenie kilka, kilkanaście wykresów; 1-liczba wierszy, jaką chcemy uzyskać w naszej siatce wykresów, 2-liczba kolumn, 1-odnosi się do 1 wykresu
plt.plot([0, 1, 2], [3, 2, 5])
plt.subplot(122) #drugi wykres
plt.plot([0, 1, 2], [3, 1, 4], 'r--') #r-- oznacza linię przyrywaną

# %%
fig = plt.figure(figsize=(12, 8)) #ręczne kontrolowanie rozmiarów wykresów

plt.subplot(131)
plt.plot([0, 1, 2], [3, 2, 5])
plt.subplot(132)
plt.plot([0, 1, 2], [3, 1, 4], 'r--')
plt.subplot(133)
plt.plot([0, 1, 2], [3, 1, 4], 'ro') #wykres punktowy

# %% [markdown]
# ### <a name='3'> </a> Wykresy słupkowe

# %%
_ = plt.bar(x=[0, 1, 2, 3], height=[1.2, 3.2, 1.2, 5.2])

# %%
plt.bar(x=['a', 'b', 'c', 'd'], height=[1.2, 3.2, 1.2, 5.2])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(y=['a', 'b', 'c', 'd'], width=[1.2, 3.2, 1.2, 5.2]) #barh - wykres horyzontalny
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### <a name='4'> </a> Wykresy punktowe

# %%
x1 = np.random.randn(300)
x2 = np.random.randn(300)

plt.scatter(x=x1, y=x2)

# %%
x3 = np.random.randn(300) * 50 

plt.scatter(x=x1, y=x2, s=x3) #parametr s oznacza różne wielkości kropek na wykresie
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
plt.scatter(x=x1, y=x2, s=x3, alpha=0.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
